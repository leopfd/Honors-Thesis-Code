# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,3,0.001)
sigup = np.array([0.23, 0.26, 0.39, 0.12, 0.17, 0.25, 0.23])
sigdn = np.array([0.44, 0.24, 0.40, 0.28, 0.14, 0.29, 0.44])
sig = (sigup + sigdn)/2.0
gam = np.array([1.49, 1.78, 2.15, 1.98, 1.40, 0.45, 1.49])
fx = np.zeros((len(gam), len(x)))
for i in range(len(gam)):
    fx[i, :] = (1./(sig[i]*np.sqrt(2.0*np.pi))) * np.exp(-0.5*((x-gam[i])/sig[i])**2)

plt.plot(x, np.sum(fx, axis=0)/np.sum(fx),'b')
plt.xlabel('$\Gamma$')
plt.ylabel('PDF')
plt.show()

# %%
x = np.arange(0, 3, 0.001)
sigup = np.array([0.23, 0.26, 0.39, 0.12, 0.17, 0.25, 0.23])
sigdn = np.array([0.44, 0.24, 0.40, 0.28, 0.14, 0.29, 0.44])
sig = (sigup + sigdn)/2.0
gam = np.array([1.49, 1.78, 2.15, 1.98, 1.40, 0.45, 1.49])
fx = np.zeros((len(gam), len(x)))
for i in range(len(gam)):
    fx[i, :] = (1./(sig[i]*np.sqrt(2.0*np.pi))) * np.exp(-0.5*((x-gam[i])/sig[i])**2)

# Calculate the maximum likelihood estimate of the mean and standard deviation
mean_ml, std_ml = norm.fit(x, loc=np.mean(gam), scale=np.mean(sig))

print(f"Maximum likelihood estimate of the mean: {mean_ml:.3f}")
print(f"Maximum likelihood estimate of the standard deviation: {std_ml:.3f}")

# Plot the original histogram
plt.plot(x, np.sum(fx, axis=0)/np.sum(fx), label='Original', alpha=0.7, color='b')

# Plot the maximum likelihood estimate distribution
p_ml = norm.pdf(x, loc=mean_ml, scale=std_ml)
plt.plot(x, p_ml/np.sum(p_ml), label='MLE',c='r')

plt.xlabel('$\Gamma$')
plt.ylabel('PDF')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8     fx[i, :] = (1./(sig[i]*np.sqrt(2.0*np.pi))) * np.exp(-0.5*((x-gam[i])/sig[i])**2)
#      10 # Calculate the maximum likelihood estimate of the mean and standard deviation
# ---> 11 mean_ml, std_ml = norm.fit(x, loc=np.mean(gam), scale=np.mean(sig))
#      13 print(f"Maximum likelihood estimate of the mean: {mean_ml:.3f}")
#      14 print(f"Maximum likelihood estimate of the standard deviation: {std_ml:.3f}")
#
# NameError: name 'norm' is not defined

# %%
sigup = np.array([0.23, 0.26, 0.39, 0.12, 0.17, 0.25, 0.23])
sigdn = np.array([0.44, 0.24, 0.40, 0.28, 0.14, 0.29, 0.44])
sig = (sigup + sigdn)/2.0
gam = np.array([1.49, 1.78, 2.15, 1.98, 1.40, 0.45, 1.49])

# Calculate the maximum likelihood estimate of the mean and standard deviation
mean_ml, std_ml = norm.fit(gam, loc=np.mean(gam), scale=np.mean(sig))

# Plot the histogram of the original data
plt.hist(gam, bins=25, density=True, alpha=0.5, color='b', label='Original')

# Calculate the x values for plotting the original probability density function
x = np.linspace(0, 3, 1000)

# Plot the maximum likelihood estimate distribution
p_ml = norm.pdf(x, loc=mean_ml, scale=std_ml)
plt.plot(x, p_ml, 'r', label='MLE')

plt.xlabel('$\Gamma$')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 gam = np.array([1.49, 1.78, 2.15, 1.98, 1.40, 0.45, 1.49])
#       6 # Calculate the maximum likelihood estimate of the mean and standard deviation
# ----> 7 mean_ml, std_ml = norm.fit(gam, loc=np.mean(gam), scale=np.mean(sig))
#       9 # Plot the histogram of the original data
#      10 plt.hist(gam, bins=25, density=True, alpha=0.5, color='b', label='Original')
#
# NameError: name 'norm' is not defined

# %%
x = np.arange(0,3.5,0.001)
sigup = np.array([0.60, 0.43, 0.49, 1.3, 1.1, 0.60])
sigdn = np.array([0.56, 0.66, 0.29, 0.80, 0.70, 0.60])
sig = (sigup + sigdn)/2.0
nh = np.array([0.56, 3.1, 2.9, 31, 2.8, 0.6])
fx = np.zeros((len(nh), len(x)))
for i in range(len(nh)):
    fx[i, :] = (1./(sig[i]*np.sqrt(2.0*np.pi))) * np.exp(-0.5*((x-nh[i])/sig[i])**2)

plt.plot(x, np.sum(fx, axis=0)/np.sum(fx),'b')
plt.xlabel('nH')
plt.ylabel('PDF')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,3,0.0001)
nh = np.array([1.52916, 0.308899, 0.966689, 0.50935, 2.47574, 0.255814, 0.0540607, 1.42264, 0.101348, 0.148519, 0.356382, 0.151387, 0.11525, 0.216297, 0.0222044, 1.25352, 0.252052])
sig = np.array([0.690634, 0.178338, 0.648277, 0.161661, 0.261954, 0.143264, 0.0960991, 0.536091, 0.030411, 0.072200, 0.197066, 0.141957, 0.192976, 0.190288, 0.0964007, 0.642362, 0.203248])
fx = np.zeros((len(nh), len(x)))
for i in range(len(nh)):
    fx[i, :] = (1./(sig[i]*np.sqrt(2.0*np.pi))) * np.exp(-0.5*((x-nh[i])/sig[i])**2)

plt.title('Error Weighted $N_H$ Distribution')
plt.plot(x, np.sum(fx, axis=0)/np.sum(fx),'b', label=('$N_H$ Probability Distribution'))
plt.xlabel('$N_H$')
plt.ylabel('PDF')
plt.xscale('log')
#plt.legend()
plt.show()

plt.title('Original $N_H$ Data')
plt.xlabel('$log(N_H)$')
plt.ylabel('Counts')
plt.hist(nh, bins=25, density=True, alpha=0.5, color='b', label='Original $N_H$ Data')
#plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 3, 0.0001)
nh = np.array([1.52916, 0.308899, 0.966689, 0.50935, 2.47574, 0.255814, 0.0540607, 1.42264, 0.101348, 0.148519, 0.356382, 0.151387, 0.11525, 0.216297, 0.0222044, 1.25352, 0.252052])
sig = np.array([0.690634, 0.178338, 0.648277, 0.161661, 0.261954, 0.143264, 0.0960991, 0.536091, 0.030411, 0.072200, 0.197066, 0.141957, 0.192976, 0.190288, 0.0964007, 0.642362, 0.203248])
fx = np.zeros((len(nh), len(x)))

plt.figure(figsize=(8, 6))
plt.xlabel('$\log(N_H)$', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.title('Distribution of $\log(N_H)$', fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Plot individual normal distributions
for i in range(len(nh)):
    individual_distribution = (1. / (sig[i] * np.sqrt(2.0 * np.pi))) * np.exp(-0.5 * ((x - nh[i]) / sig[i]) ** 2)
    plt.plot(x, individual_distribution, label=f'$N_H$ {i+1}', alpha=0.7)

# Set tick parameters
plt.tick_params(axis='both', direction='in', which='both', width=1)

plt.tight_layout()
plt.legend(fontsize=12)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 3, 0.0001)
nh = np.array([1.52916, 0.308899, 0.966689, 0.50935, 2.47574, 0.255814, 0.0540607, 1.42264, 0.101348, 0.148519, 0.356382, 0.151387, 0.11525, 0.216297, 0.0222044, 1.25352, 0.252052])
sig = np.array([0.690634, 0.178338, 0.648277, 0.161661, 0.261954, 0.143264, 0.0960991, 0.536091, 0.030411, 0.072200, 0.197066, 0.141957, 0.192976, 0.190288, 0.0964007, 0.642362, 0.203248])
fx = np.zeros((len(nh), len(x)))

for i in range(len(nh)):
    fx[i, :] = (1. / (sig[i] * np.sqrt(2.0 * np.pi))) * np.exp(-0.5 * ((x - nh[i]) / sig[i]) ** 2)

plt.figure(figsize=(8, 6))
plt.hist(np.log(nh), bins=25, density=True, alpha=0.5, color='b', label='Original $N_H$ Data')
plt.xlabel('$\log(N_H)$', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.title('Distribution of $\log(N_H)$', fontsize=16)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Set tick parameters
plt.tick_params(axis='both', direction='in', which='both', width=1)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 3, 0.0001)
nh = np.array([1.52916, 0.308899, 0.966689, 0.50935, 2.47574, 0.255814, 0.0540607, 1.42264, 0.101348, 0.148519, 0.356382, 0.151387, 0.11525, 0.216297, 0.0222044, 1.25352, 0.252052])
sig = np.array([0.690634, 0.178338, 0.648277, 0.161661, 0.261954, 0.143264, 0.0960991, 0.536091, 0.030411, 0.072200, 0.197066, 0.141957, 0.192976, 0.190288, 0.0964007, 0.642362, 0.203248])

plt.figure(figsize=(8, 6))

for i in range(len(nh)):
    # Generate normal distribution for each nh value
    dist = np.random.normal(np.log(nh[i]), sig[i], 1000)
    plt.hist(dist, bins=15, density=True, alpha=0.5, label=f'$N_H$={nh[i]}$\pm${sig[i]}')

plt.xlabel('$\log(N_H)$', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.title('Distribution of $\log(N_H)$ with Errors', fontsize=16)
plt.legend(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)

# Set tick parameters
plt.tick_params(axis='both', direction='in', which='both', width=1)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 3, 0.0001)
nh = np.array([1.52916, 0.308899, 0.966689, 0.50935, 2.47574, 0.255814, 0.0540607, 1.42264, 0.101348, 0.148519, 0.356382, 0.151387, 0.11525, 0.216297, 0.0222044, 1.25352, 0.252052])
sig = np.array([0.690634, 0.178338, 0.648277, 0.161661, 0.261954, 0.143264, 0.0960991, 0.536091, 0.030411, 0.072200, 0.197066, 0.141957, 0.192976, 0.190288, 0.0964007, 0.642362, 0.203248])

plt.figure(figsize=(8, 6))

# Initialize an empty array to store all the distributions
all_distributions = []

for i in range(len(nh)):
    # Generate normal distribution for each nh value
    dist = np.random.normal(np.log(nh[i]), sig[i], 1000)
    all_distributions.extend(dist)  # Add current distribution to the array
    
# Plot the combined distribution
plt.hist(all_distributions, bins=18, density=True, alpha=0.5, color='b', label='Combined Distributions')

plt.xlabel('$\log(N_H)$', fontsize=14)
plt.ylabel('Probability Density', fontsize=14)
plt.title('Error Weighted Distribution of $\log(N_H)$', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.7)

# Set tick parameters
plt.tick_params(axis='both', direction='in', which='both', width=1)

plt.tight_layout()
#plt.show()
plt.savefig('fig2.pdf')
